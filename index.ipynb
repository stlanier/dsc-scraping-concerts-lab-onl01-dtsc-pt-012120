# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
# just a bit of exploration

# html_page = requests.get('https://www.residentadvisor.net/events')
# soup = BeautifulSoup(html_page.content, 'html.parser')
# events_div = soup.find('div', id='event-listing')
# events_list = events_div.findAll('article')
# events_list[0].find('p', 'attending').find('span').text

# %%
def scrape_events(events_page_url):
    Event_Name = []
    Venue = []
    Event_Date = []
    Number_of_Attendees = []
    
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    events_div = soup.find('div', id='event-listing')
    events_list = events_div.findAll('article')
    for event in events_list:
        Event_Name.append(event.find('h1', class_='event-title').find('a').text)
        Venue.append(event.findAll('a')[-1].text)
        Event_Date.append(event.find('time')['datetime'])
        num_attending = 0;
        if event.find('p', 'attending'):
            num_attending = int(event.find('p', 'attending').find('span').text)
        Number_of_Attendees.append(num_attending)
    
    df = pd.DataFrame([Event_Name, Venue, Event_Date, Number_of_Attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    df['Number_of_Attendees'] = df['Number_of_Attendees'].astype('int')
    df['Event_Date'] = pd.to_datetime(df['Event_Date'])
    return df

# %%
df = scrape_events('https://www.residentadvisor.net/events')
df
# Out:
#                                           Event_Name            Venue  \
# 0                          Field Trip 109: Eli Brown      Q Nightclub
# 1  Haüsed: Diet Panda B2B David Hayes, Aivi Lo & ...         Kremwerk
# 2  Shameless 17 Year Anniversary Party with DeWal...           Re-Bar
# 3  People Music presents // Stylust Activated Tou...         Kremwerk
# 4                             5K Feat. Arnold & Lane         Kremwerk
# 5                 Bottom Forty presents Alison Swing         Kremwerk
# 6                      Diggin' Deep with Dave Seaman  The Monkey Loft
# 7                 Haute Sauce: Falcons & Andre Power      Q Nightclub
#
#   Event_Date  Number_of_Attendees
# 0 2020-02-27                    1
# 1 2020-02-27                    1
# 2 2020-02-28                    9
# 3 2020-02-28                    1
# 4 2020-02-28                    1
# 5 2020-02-29                    4
# 6 2020-02-29                    1
# 7 2020-02-29                    0

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# more exploration to make sure what's going into my function works, step by step.

# url = 'https://www.residentadvisor.net/events/'
# html_page = requests.get(url)
# soup = BeautifulSoup(html_page.content, 'html.parser')
# next_location = soup.find('li', id='liNext').find('a')['href']
# next_page_url = url[:url.rfind('/events')] + next_location
# display(next_page_url)

# %%
def next_page(url):
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    next_page_url = ''
    if soup.find('li', class_='but arrow-right right disabled', id='liNext'):
        next_page_url = ''
    else:
        next_location = soup.find('li', id='liNext').find('a')['href']
        next_page_url = url[:url.rfind('/events')] + next_location
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
# url = 'https://www.residentadvisor.net/events/us/seattle/week/2020-06-23'
# next_page(url)
# html_page = requests.get(url)
# soup = BeautifulSoup(html_page.content, 'html.parser')
# soup.find('li', id='liNext')

# next_page_url = ''
# if soup.find('li', id='liNext').find('a')['href']:
#     next_location = soup.find('li', id='liNext').find('a')['href']
#     next_page_url = url[:url.rfind('/events')] + next_location
# else:
#     next_page_url = ''

# %%
url = 'https://www.residentadvisor.net/events'
print(url)
df = scrape_events(url)

while next_page(url):
    url = next_page(url)
    print(url)
    df = df.append(scrape_events(url), ignore_index=True)
    
df.shape
# Out:
# https://www.residentadvisor.net/events
# https://www.residentadvisor.net/events/us/seattle/week/2020-03-03
# https://www.residentadvisor.net/events/us/seattle/week/2020-03-10
# https://www.residentadvisor.net/events/us/seattle/week/2020-03-17
# https://www.residentadvisor.net/events/us/seattle/week/2020-03-24
# https://www.residentadvisor.net/events/us/seattle/week/2020-03-31
# https://www.residentadvisor.net/events/us/seattle/week/2020-04-07
# https://www.residentadvisor.net/events/us/seattle/week/2020-04-14
# https://www.residentadvisor.net/events/us/seattle/week/2020-04-21
# https://www.residentadvisor.net/events/us/seattle/week/2020-04-28
# https://www.residentadvisor.net/events/us/seattle/week/2020-05-05
# https://www.residentadvisor.net/events/us/seattle/week/2020-05-12
# https://www.residentadvisor.net/events/us/seattle/week/2020-05-19
# https://www.residentadvisor.net/events/us/seattle/week/2020-05-26
# https://www.residentadvisor.net/events/us/seattle/week/2020-06-02
# https://www.residentadvisor.net/events/us/seattle/week/2020-06-09
# https://www.residentadvisor.net/events/us/seattle/week/2020-06-16
# https://www.residentadvisor.net/events/us/seattle/week/2020-06-23
# (56, 4)

# %%
df
# Out:
#                                            Event_Name  \
# 0                           Field Trip 109: Eli Brown
# 1   Haüsed: Diet Panda B2B David Hayes, Aivi Lo & ...
# 2   Shameless 17 Year Anniversary Party with DeWal...
# 3   People Music presents // Stylust Activated Tou...
# 4                              5K Feat. Arnold & Lane
# 5                  Bottom Forty presents Alison Swing
# 6                       Diggin' Deep with Dave Seaman
# 7                  Haute Sauce: Falcons & Andre Power
# 8                               Night School: Gattuso
# 9                                     Haüsed: Flava D
# 10                      Field Trip 110: Spencer Brown
# 11                                   Telefon Tel Aviv
# 12                                            No Mana
# 13                                 Future Funktion VI
# 14                                Depth: Magda & Aida
# 15  1luv Proudly presents Grensta - Recess & The 1...
# 16  Bounce Brunch *Spring??* ft Tyler Morrison & T...
# 17                Reflect 1st Saturday: March Edition
# 18                            Fennesz, Britton Powell
# 19                           Haüsed x Depth: La Fleur
# 20                              Field Trip 111: Malaa
# 21                         Tenth Aesthetic: Nancy Dru
# 22                           Secondnature: Mala Junta
# 23  Noise Complaint feat. Will Clarke (Open-to-Close)
# 24                     Night School: Miami Horror DJs
# 25                       OS: Davis Galvin, DJ Illegit
# 26                                          Dom Dolla
# 27                                 Northleft: Emerald
# 28           Häused x Depth: Julian Jeweil [Drumcode]
# 29                            Field Trip 112: Odd Mob
# 30                              Persona by Studio 4/4
# 31  Shook: Innamind Recordings Showcase with Ago, ...
# 32                            THIS! with Chris Stussy
# 33                                            Ata Kak
# 34                          Field Trip 113: Wax Motif
# 35                                 Depth: Robert Hood
# 36  Shameless & Tremulant Pres. Smash TV (Get Phys...
# 37                             Rough Draft: Awakening
# 38                  Diggin' Deep: Uniting Souls Music
# 39                        Showcez feat. Culoe De Song
# 40                             Field Trip 114: Mercer
# 41   Horse Meat Disco with Bottom Forty & Innerflight
# 42                               Night School: Getter
# 43                                             Tchami
# 44                              Yves Tumor & Its Band
# 45                  Field Trip 116: Ben Bohmer (Live)
# 46                                        Be Svendsen
# 47                   Mat Zo presents The Next Chapter
# 48  Noise Complaint feat. Option4 (Yuri's Night Af...
# 49                        Field Trip 116: Kyle Watson
# 50                            THIS! with Hector Couto
# 51    People Music presents // J:Kenzo, The Librarian
# 52  Nightmares on Wax Smokers Delight 25th Anniver...
# 53                                Night School: Ducky
# 54                                    The Timbre Room
# 55                Kraftwerk 50th Anniversary 3-D Tour
#
#                              Venue Event_Date  Number_of_Attendees
# 0                      Q Nightclub 2020-02-27                    1
# 1                         Kremwerk 2020-02-27                    1
# 2                           Re-Bar 2020-02-28                    9
# 3                         Kremwerk 2020-02-28                    1
# 4                         Kremwerk 2020-02-28                    1
# 5                         Kremwerk 2020-02-29                    4
# 6                  The Monkey Loft 2020-02-29                    1
# 7                      Q Nightclub 2020-02-29                    0
# 8                      Q Nightclub 2020-03-03                    0
# 9                         Kremwerk 2020-03-05                    2
# 10                     Q Nightclub 2020-03-05                    1
# 11                          Neumos 2020-03-05                    1
# 12                     Q Nightclub 2020-03-06                    1
# 13                        Kremwerk 2020-03-06                    1
# 14                        Kremwerk 2020-03-06                    1
# 15                 The Monkey Loft 2020-03-06                    1
# 16                  The Blu Grouse 2020-03-07                    2
# 17  Vermillion Art Gallery and Bar 2020-03-07                    0
# 18           Columbia City Theatre 2020-03-08                    3
# 19                        Kremwerk 2020-03-12                    3
# 20                     Q Nightclub 2020-03-12                    2
# 21                        Kremwerk 2020-03-12                    0
# 22        Secondnature: Mala Junta 2020-03-13                    3
# 23                        Kremwerk 2020-03-13                    2
# 24                     Q Nightclub 2020-03-13                    0
# 25                            Pony 2020-03-14                    2
# 26                    Showbox SoDo 2020-03-14                    1
# 27                        Kremwerk 2020-03-17                    0
# 28                        Kremwerk 2020-03-19                    3
# 29                     Q Nightclub 2020-03-19                    0
# 30                 The Monkey Loft 2020-03-20                    2
# 31                        Kremwerk 2020-03-20                    1
# 32                 The Monkey Loft 2020-03-21                    3
# 33                   The Crocodile 2020-03-24                    1
# 34                     Q Nightclub 2020-03-26                    1
# 35                        Kremwerk 2020-03-27                    2
# 36                 The Monkey Loft 2020-03-27                    1
# 37                        Kremwerk 2020-03-28                    1
# 38                 The Monkey Loft 2020-03-28                    0
# 39                 The Underground 2020-04-02                    2
# 40                     Q Nightclub 2020-04-02                    0
# 41                 The Monkey Loft 2020-04-03                    1
# 42                     Q Nightclub 2020-04-03                    0
# 43                    Showbox SoDo 2020-04-04                    0
# 44                          Neumos 2020-04-05                    3
# 45                     Q Nightclub 2020-04-09                    5
# 46                   Nectar Lounge 2020-04-09                    3
# 47                     Q Nightclub 2020-04-10                    0
# 48                        Kremwerk 2020-04-11                    2
# 49                     Q Nightclub 2020-04-16                    0
# 50                 The Monkey Loft 2020-04-18                    2
# 51                        Kremwerk 2020-04-18                    0
# 52                   Nectar Lounge 2020-04-24                    6
# 53                     Q Nightclub 2020-04-24                    0
# 54                 The Timbre Room 2020-05-22                    2
# 55                   Moore Theater 2020-06-19                    1

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
